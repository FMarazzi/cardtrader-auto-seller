# %%
import requests

# %%
token = "eyJhbGciOiJSUzI1NiJ9..f0P34Q8hOY_oN6srWSAlY5IYatQV_Vd1BOmUwuDwGjAlSSpIAI1LOBa56HX7n-SbNHjyTUPvyXDSHo-OTKUZqEHBIQmsJlLjbJVFFPuwQL4xmbD_n3X_ZusCJGFf4649dmt89U8eo3RZ6jpUCPNvahdcqfL_BS8_8fOHIXkni-uFp7am1woxwUiyE0iPzw4G78zdX5iXQZRXsdwgz5zS1XM-J9HIYThWclvl22xxbgpuxtajle4qUJ048B7f0d4iMi5YmD8O-AY70afh6mvG5UJiou4BpqTIX9N1PULqpUcC0O1KtWO0Bdss2D1VO8CM6Hf7ottef3ugxkAVi-5GSA"
endpoint = "https://api.cardtrader.com/api/v2/info"
data = {"ip": "1.1.2.3"}
headers = {"Authorization": f"Bearer {token}"}

print(requests.get(endpoint, headers=headers).json())
# Out:
# {'shared_secret': 'f24572d46397b151cff3ba19f84c45f5', 'name': 'Francesco marazzi90 App 20240919174928', 'id': 12020}

# %%
token = "eyJhbGciOiJSUzI1NiJ9..f0P34Q8hOY_oN6srWSAlY5IYatQV_Vd1BOmUwuDwGjAlSSpIAI1LOBa56HX7n-SbNHjyTUPvyXDSHo-OTKUZqEHBIQmsJlLjbJVFFPuwQL4xmbD_n3X_ZusCJGFf4649dmt89U8eo3RZ6jpUCPNvahdcqfL_BS8_8fOHIXkni-uFp7am1woxwUiyE0iPzw4G78zdX5iXQZRXsdwgz5zS1XM-J9HIYThWclvl22xxbgpuxtajle4qUJ048B7f0d4iMi5YmD8O-AY70afh6mvG5UJiou4BpqTIX9N1PULqpUcC0O1KtWO0Bdss2D1VO8CM6Hf7ottef3ugxkAVi-5GSA"
endpoint = "https://api.cardtrader.com/api/v2/products/export"
data = {"ip": "1.1.2.3"}
headers = {"Authorization": f"Bearer {token}"}

print(requests.get(endpoint, headers=headers).json())
# Out:
# [{'uploaded_images': [], 'quantity': 1, 'description': '', 'price_cents': 189, 'blueprint_id': 225079, 'properties_hash': {'condition': 'Near Mint', 'mtg_card_colors': 'C', 'tournament_legal': True, 'collector_number': '229a', 'cmc': '0', 'signed': False, 'mtg_foil': True, 'mtg_language': 'en', 'altered': False, 'mtg_rarity': 'Rare'}, 'expansion': {'id': 2912}, 'category_id': 1, 'user_id': 248056, 'graded': False, 'id': 273745182, 'tag': '', 'bundle_size': 1, 'user_data_field': None, 'price_currency': 'EUR', 'game_id': 1, 'name_en': 'Storybook Ride'}]

# %%
token = "eyJhbGciOiJSUzI1NiJ9..f0P34Q8hOY_oN6srWSAlY5IYatQV_Vd1BOmUwuDwGjAlSSpIAI1LOBa56HX7n-SbNHjyTUPvyXDSHo-OTKUZqEHBIQmsJlLjbJVFFPuwQL4xmbD_n3X_ZusCJGFf4649dmt89U8eo3RZ6jpUCPNvahdcqfL_BS8_8fOHIXkni-uFp7am1woxwUiyE0iPzw4G78zdX5iXQZRXsdwgz5zS1XM-J9HIYThWclvl22xxbgpuxtajle4qUJ048B7f0d4iMi5YmD8O-AY70afh6mvG5UJiou4BpqTIX9N1PULqpUcC0O1KtWO0Bdss2D1VO8CM6Hf7ottef3ugxkAVi-5GSA"
endpoint = "https://api.cardtrader.com/api/v2/expansions"
data = {"ip": "1.1.2.3"}
headers = {"Authorization": f"Bearer {token}"}

print(requests.get(endpoint, headers=headers).json())
# Out:
# [{'id': 1, 'game_id': 1, 'code': 'gnt', 'name': 'Game Night'}, {'id': 3, 'game_id': 1, 'code': 'pgrn', 'name': 'Guilds of Ravnica Promos'}, {'id': 4, 'game_id': 1, 'code': 'gk1', 'name': 'GRN Guild Kit'}, {'id': 6, 'game_id': 1, 'code': 'grn', 'name': 'Guilds of Ravnica'}, {'id': 7, 'game_id': 1, 'code': 'med', 'name': 'Guilds of Ravnica: Mythic Edition'}, {'id': 8, 'game_id': 1, 'code': 'c18', 'name': 'Commander 2018'}, {'id': 9, 'game_id': 1, 'code': 'htr17', 'name': '2017 Heroes of the Realm'}, {'id': 10, 'game_id': 1, 'code': 'ps18', 'name': 'San Diego Comic-Con 2018'}, {'id': 11, 'game_id': 1, 'code': 'pss3', 'name': 'M19 Standard Showdown'}, {'id': 12, 'game_id': 1, 'code': 'm19', 'name': 'Core Set 2019'}, {'id': 13, 'game_id': 1, 'code': 'pm19', 'name': 'Core Set 2019 Promos'}, {'id': 14, 'game_id': 1, 'code': 'gs1', 'name': 'Global Series Jiang Yanggu & Mu Yanling'}, {'id': 15, 'game_id': 1, 'code': 'ss1', 'name': 'Signature Spellbook: Jace'}, {'id': 16, 'game_id': 1, 'code':
# ...

# %%
endpoint = "https://api.cardtrader.com/api/v2/info"
data = {"ip": "1.1.2.3"}
headers = {"Authorization": "Bearer MYREALLYLONGTOKENIGOT"}

print(requests.post(endpoint, data=data, headers=headers).json())
